# %% [markdown]
# **Submitted By: Zainab Anwaar**

# %% [markdown]
# **CMS ID: 339636**

# %% [markdown]
# Task 1) Loading and Preprocessing Data

# %% [markdown]
# Importing modules and libraries

# %%
import pandas as pd 
import numpy as np 
from sklearn import datasets
from sklearn import metrics
import seaborn as sns
from matplotlib.colors import ListedColormap
from sklearn import inspection
from sklearn.model_selection import cross_val_score,KFold
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt 
# %matplotlib inline 
import graphviz

# %% [markdown]
# Loading Data

# %%
iris = datasets.load_iris()
print('Dataset structure= ', dir(iris))
# Out:
# Dataset structure=  ['DESCR', 'data', 'data_module', 'feature_names', 'filename', 'frame', 'target', 'target_names']

# %%
df = pd.DataFrame(iris.data, columns = iris.feature_names)
df['target'] = iris.target
df['flower_species'] = df.target.apply(lambda x : iris.target_names[x]) # Each value from 'target' is used as index to get corresponding value from 'target_names' 

print('Unique target values=',df['target'].unique())

df.sample(5)
# Out:
# Unique target values= [0 1 2]
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 115                6.4               3.2                5.3               2.3
# 96                 5.7               2.9                4.2               1.3
# 38                 4.4               3.0                1.3               0.2
# 75                 6.6               3.0                4.4               1.4
# 126                6.2               2.8                4.8               1.8
#
#      target flower_species
# 115       2      virginica
# 96        1     versicolor
# 38        0         setosa
# 75        1     versicolor
# 126       2      virginica

# %%
X = df[['petal length (cm)', 'petal width (cm)']]
y = df[['target']]

# %% [markdown]
# Task 2) Implementing KNN Algorithm

# %% [markdown]
# Splitting in Test and Train Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# Data Points of the Training Data

# %%
plt.figure()
x_plt=X_train['petal length (cm)']
y_plt=X_train['petal width (cm)']
plt.scatter(x_plt, y_plt)

plt.title("Data points")
plt.show()

# %% [markdown]
# Classification with KNN

# %%
error_rates = []
scores=[]



colors={0:'red', 1:'green', 2:'purple'}
color_list=[]
for i in y_train[target]:
  color_list.append(colors[i])


for k in range(1,11):
  knn=KNeighborsClassifier(n_neighbors=k)
  score=np.mean(cross_val_score(knn,X,y,cv=5))
  scores.append(score)
  knn.fit(X_train,y_train)
  error=1-score
  error_rates.append(error)
  plt.title(f"Plot for K={k}")
  plt.scatter(x_plt,y_plt,c=color_list)
  plt.xlabel('Petal Length (cm)')
  plt.ylabel('Petal Width (cm)')
  plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.8/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.8/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,11), error_rates, color='purple', marker='o', markerfacecolor='red', markersize=10)
plt.title('Error rate VS K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %% [markdown]
# Task 3: Selecting Optimal Value of K

# %%
error_rates = []
scores=[]
K=[]
for k in range(1,11):
    knn_model = KNeighborsClassifier(n_neighbors=k)
    score=np.mean(cross_val_score(knn_model,X,y,cv=5))
    scores.append(score)
    knn_model.fit(X_train,y_train) 
    error=1-score
    error_rates.append(error)
    K.append(k)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.8/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.8/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,11), error_rates, color='blue', linestyle='dashed', marker='o', markerfacecolor='red', markersize=10)

plt.title('Error rate VS K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(X_train, y_train)
pred = knn.predict(X_test)

print('WITH K=5')
print('\n')
print(metrics.confusion_matrix(y_test, pred))
print('\n')
print(metrics.classification_report(y_test, pred))
# Out:
# WITH K=5
#
#
# [[11  0  0]
#  [ 0 13  0]
#  [ 0  0  6]]
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00         6
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
# /usr/local/lib/python3.8/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %% [markdown]
# From the above graph, the K=5 is the optimal value as the error rate tends to be 0 for k=5 and k=6.
